# %%
import sqlalchemy

# %%
import pymysql

# %%
#connection created in between sql and python 
engine = sqlalchemy.create_engine('mysql+pymysql://root:masaischool123@localhost:3306/PowerBI')

# %%
import pandas as pd

# %%
#load customers, purchase, products table from sqlDB
customers = pd.read_sql_table("customers",engine)
purchase = pd.read_sql_table("purchase",engine)
products=pd.read_sql_table("products",engine)

# %%
customers
# Out:
#      customerid       CustomerName  \
# 0          3001         Ryan Wiley
# 1          3002    Crystal Roberts
# 2          3003   Christina Vargas
# 3          3004       Kevin Gordon
# 4          3005  Christopher Roach
# ..          ...                ...
# 995        3996   Tracy Fitzgerald
# 996        3997   Benjamin Randall
# 997        3998        David Grant
# 998        3999    Kristi Williams
# 999        4000      Alyssa Thomas
#
#                                                Country
# 0                                              Senegal
# 1    British Indian Ocean Territory (Chagos Archipe...
# 2                                              Romania
# 3                                                Malta
# 4                                                Niger
# ..                                                 ...
# 995                                      Guinea-Bissau
# 996                                        Philippines
# 997                        French Southern Territories
# 998                                             Norway
# 999                                               Fiji
#
# [1000 rows x 3 columns]

# %%
products
# Out:
#     productid      productname  productcategory
# 0         301  Air Conditioner  Home Appliances
# 1         302          Blender  Home Appliances
# 2         303           Camera      Electronics
# 3         304     Coffee Maker  Home Appliances
# 4         305  Electric Kettle  Home Appliances
# 5         306       Headphones      Electronics
# 6         307           Heater  Home Appliances
# 7         308           Laptop      Electronics
# 8         309        Microwave  Home Appliances
# 9         310          Printer      Electronics
# 10        311     Refrigerator  Home Appliances
# 11        312           Router      Electronics
# 12        313       Smart Bulb      Electronics
# 13        314       Smartphone      Electronics
# 14        315       Smartwatch      Electronics
# 15        316           Tablet      Electronics
# 16        317       Television      Electronics
# 17        318          Toaster  Home Appliances
# 18        319   Vacuum Cleaner  Home Appliances
# 19        320  Washing Machine  Home Appliances

# %%
purchase
# Out:
#      customerid  productid  purchaseid  transactionid purchasedate  \
# 0          3001        301        5001            224   2023-06-26
# 1          3002        302        5002            650   2023-06-26
# 2          3003        303        5003            152   2023-06-27
# 3          3004        304        5004            376   2023-06-27
# 4          3005        305        5005            635   2023-06-27
# ..          ...        ...         ...            ...          ...
# 995        3996       1296        5996            439   2024-06-24
# 996        3997       1297        5997            864   2024-06-24
# 997        3998       1298        5998             37   2024-06-25
# 998        3999       1299        5999             83   2024-06-25
# 999        4000       1300        6000            854   2024-06-25
#
#      purchaseprice  purchasequantity  \
# 0            54.96                 3
# 1           477.05                 1
# 2           579.06                 3
# 3           757.42                 3
# 4           316.81                 1
# ..             ...               ...
# 995         401.99                 1
# 996         527.87                 5
# 997         568.75                 5
# 998         813.03                 2
# 999         816.81                 3
#
#                                                country
# 0                                              Senegal
# 1    British Indian Ocean Territory (Chagos Archipe...
# 2                                              Romania
# 3                                                Malta
# 4                                                Niger
# ..                                                 ...
# 995                                      Guinea-Bissau
# 996                                        Philippines
# 997                        French Southern Territories
# 998                                             Norway
# 999                                               Fiji
#
# [1000 rows x 8 columns]

# %%
purchase.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerid        1000 non-null   int64
#  1   productid         1000 non-null   int64
#  2   purchaseid        1000 non-null   int64
#  3   transactionid     1000 non-null   int64
#  4   purchasedate      1000 non-null   datetime64[ns]
#  5   purchaseprice     1000 non-null   float64
#  6   purchasequantity  1000 non-null   int64
#  7   country           1000 non-null   object
# dtypes: datetime64[ns](1), float64(1), int64(5), object(1)
# memory usage: 62.6+ KB

# %%
#Calculate total purchases, total revenue, and average purchase value.
Total_purchase = sum(purchase["purchaseprice"])
Total_purchase
# Out:
# 489274.72

# %%
#average of total purchase value  
Average_purchase = purchase["purchaseprice"].mean()
Average_purchase
# Out:
# 489.27471999999995

# %%
#top cutomers and purchasing behaviour
# Sorting by 'Spending' to find top customers by highest spending
merge1= pd.merge(purchase,customers,on="customerid")
merge2= pd.merge(merge1,products,left_on="productid",right_on="productid")
merge2
# Out:
#     customerid  productid  purchaseid  transactionid purchasedate  \
# 0         3001        301        5001            224   2023-06-26
# 1         3002        302        5002            650   2023-06-26
# 2         3003        303        5003            152   2023-06-27
# 3         3004        304        5004            376   2023-06-27
# 4         3005        305        5005            635   2023-06-27
# 5         3006        306        5006            857   2023-06-27
# 6         3007        307        5007             56   2023-06-28
# 7         3008        308        5008            397   2023-06-28
# 8         3009        309        5009            942   2023-06-28
# 9         3010        310        5010            102   2023-06-29
# 10        3011        311        5011            350   2023-06-29
# 11        3012        312        5012            716   2023-07-01
# 12        3013        313        5013            842   2023-07-01
# 13        3014        314        5014            933   2023-07-01
# 14        3015        315        5015            977   2023-07-01
# 15        3016        316        5016            271   2023-07-03
# 16        3017        317        5017            336   2023-07-03
# 17        3018        318        5018            449   2023-07-04
# 18        3019        319        5019            573   2023-07-04
# 19        3020        320        5020            805   2023-07-04
#
#     purchaseprice  purchasequantity  \
# 0           54.96                 3
# 1          477.05                 1
# 2          579.06                 3
# 3          757.42                 3
# 4          316.81                 1
# 5          121.93                 2
# 6          184.38                 4
# 7          355.32                 4
# 8          288.70                 1
# 9           49.83                 5
# 10         826.98                 1
# 11         707.49                 3
# 12         207.75                 5
# 13         213.52                 1
# 14         522.71                 2
# 15         189.04                 2
# 16         367.29                 1
# 17         536.61                 4
# 18         491.80                 2
# 19         641.93                 5
#
#                                               country        CustomerName  \
# 0                                             Senegal          Ryan Wiley
# 1   British Indian Ocean Territory (Chagos Archipe...     Crystal Roberts
# 2                                             Romania    Christina Vargas
# 3                                               Malta        Kevin Gordon
# 4                                               Niger   Christopher Roach
# 5                               Saint Kitts and Nevis     Douglas Winters
# 6                                             Eritrea       William Woods
# 7                                           Greenland       Dennis Martin
# 8                                         El Salvador       Linda Goodman
# 9                                                Cuba          Mark Jones
# 10                                        Timor-Leste          Brian York
# 11                   Saint Vincent and the Grenadines           Luis Hill
# 12                                            Burundi         Joseph Bell
# 13                                   Saint Barthelemy     Jacob Valentine
# 14                                              Chile        Joseph Smith
# 15                                              Ghana  Benjamin Singleton
# 16                                            Denmark       Colin Vaughan
# 17                                            Ecuador       Kevin Holland
# 18                                       Sierra Leone       William Lewis
# 19                                            Tunisia      Matthew Carter
#
#                                               Country      productname  \
# 0                                             Senegal  Air Conditioner
# 1   British Indian Ocean Territory (Chagos Archipe...          Blender
# 2                                             Romania           Camera
# 3                                               Malta     Coffee Maker
# 4                                               Niger  Electric Kettle
# 5                               Saint Kitts and Nevis       Headphones
# 6                                             Eritrea           Heater
# 7                                           Greenland           Laptop
# 8                                         El Salvador        Microwave
# 9                                                Cuba          Printer
# 10                                        Timor-Leste     Refrigerator
# 11                   Saint Vincent and the Grenadines           Router
# 12                                            Burundi       Smart Bulb
# 13                                   Saint Barthelemy       Smartphone
# 14                                              Chile       Smartwatch
# 15                                              Ghana           Tablet
# 16                                            Denmark       Television
# 17                                            Ecuador          Toaster
# 18                                       Sierra Leone   Vacuum Cleaner
# 19                                            Tunisia  Washing Machine
#
#     productcategory
# 0   Home Appliances
# 1   Home Appliances
# 2       Electronics
# 3   Home Appliances
# 4   Home Appliances
# 5       Electronics
# 6   Home Appliances
# 7       Electronics
# 8   Home Appliances
# 9       Electronics
# 10  Home Appliances
# 11      Electronics
# 12      Electronics
# 13      Electronics
# 14      Electronics
# 15      Electronics
# 16      Electronics
# 17  Home Appliances
# 18  Home Appliances
# 19  Home Appliances

# %%
total_customers = merge2.groupby(["customerid","CustomerName","purchasedate","productname","purchasequantity"])["purchaseprice"].sum().reset_index()
top_10_customers_by_customerid = total_customers.nlargest(10, 'purchaseprice')
top_10_customers_by_customerid
# Out:
#     customerid      CustomerName purchasedate      productname  \
# 10        3011        Brian York   2023-06-29     Refrigerator
# 3         3004      Kevin Gordon   2023-06-27     Coffee Maker
# 11        3012         Luis Hill   2023-07-01           Router
# 19        3020    Matthew Carter   2023-07-04  Washing Machine
# 2         3003  Christina Vargas   2023-06-27           Camera
# 17        3018     Kevin Holland   2023-07-04          Toaster
# 14        3015      Joseph Smith   2023-07-01       Smartwatch
# 18        3019     William Lewis   2023-07-04   Vacuum Cleaner
# 1         3002   Crystal Roberts   2023-06-26          Blender
# 16        3017     Colin Vaughan   2023-07-03       Television
#
#     purchasequantity  purchaseprice
# 10                 1         826.98
# 3                  3         757.42
# 11                 3         707.49
# 19                 5         641.93
# 2                  3         579.06
# 17                 4         536.61
# 14                 2         522.71
# 18                 2         491.80
# 1                  1         477.05
# 16                 1         367.29

# %%
#highest quantity ordered by customers
merge2.groupby("productname")["purchaseprice"].sum()
# Out:
# productname
# Air Conditioner     54.96
# Blender            477.05
# Camera             579.06
# Coffee Maker       757.42
# Electric Kettle    316.81
# Headphones         121.93
# Heater             184.38
# Laptop             355.32
# Microwave          288.70
# Printer             49.83
# Refrigerator       826.98
# Router             707.49
# Smart Bulb         207.75
# Smartphone         213.52
# Smartwatch         522.71
# Tablet             189.04
# Television         367.29
# Toaster            536.61
# Vacuum Cleaner     491.80
# Washing Machine    641.93
# Name: purchaseprice, dtype: float64

# %%
merge2.groupby("productname")["purchasequantity"].sum()
# Out:
# productname
# Air Conditioner    3
# Blender            1
# Camera             3
# Coffee Maker       3
# Electric Kettle    1
# Headphones         2
# Heater             4
# Laptop             4
# Microwave          1
# Printer            5
# Refrigerator       1
# Router             3
# Smart Bulb         5
# Smartphone         1
# Smartwatch         2
# Tablet             2
# Television         1
# Toaster            4
# Vacuum Cleaner     2
# Washing Machine    5
# Name: purchasequantity, dtype: int64

# %%
#Quarter wise sales
merge2.groupby(merge2['purchasedate'].dt.quarter)["purchaseprice"].sum()
# Out:
# purchasedate
# 2    4012.44
# 3    3878.14
# Name: purchaseprice, dtype: float64

# %%
merge2.groupby(merge2['purchasedate'].dt.year)["purchaseprice"].sum()
# Out:
# purchasedate
# 2023    7890.58
# Name: purchaseprice, dtype: float64

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns
sns.set_style("whitegrid")
sns.pairplot(top_10_customers_by_customerid) 
plt.show()

# %%
plt.bar(top_10_customers_by_customerid["productname"],top_10_customers_by_customerid["purchasequantity"])
plt.show()

# %%
#purchae behaviour of customers
customer_ids_to_filter = [3674, 3850, 3132,3780,3696,3083,3177,3775,3245,3786]

# Method 1: Using .loc with boolean indexing
top_customers_purchase_behaviour = merge1.loc[merge1['customerid'].isin(customer_ids_to_filter)]
top_customers_purchase_behaviour
# Out:
#      customerid  productid  purchaseid  transactionid purchasedate  \
# 82         3083        383        5083            615   2023-07-26
# 131        3132        432        5132            373   2023-08-11
# 176        3177        477        5177             99   2023-08-30
# 244        3245        545        5245            264   2023-09-19
# 673        3674        974        5674            463   2024-02-13
# 695        3696        996        5696            193   2024-02-20
# 774        3775       1075        5775            545   2024-03-19
# 779        3780       1080        5780            866   2024-03-21
# 785        3786       1086        5786            742   2024-03-23
# 849        3850       1150        5850            657   2024-04-25
#
#      purchaseprice  purchasequantity                   country  \
# 82          389.24                 2                  Portugal
# 131         509.21                 4                 Venezuela
# 176         602.06                 1                   Burundi
# 244         102.52                 5  Northern Mariana Islands
# 673         248.56                 4                    Turkey
# 695          70.22                 1                    Poland
# 774         641.80                 5                     Nauru
# 779         893.14                 5                   Namibia
# 785         841.46                 5                 Greenland
# 849          95.52                 3                  Suriname
#
#           CustomerName                   Country
# 82      David Mcdaniel                  Portugal
# 131        Ashley Carr                 Venezuela
# 176  Katherine Jackson                   Burundi
# 244      Amanda Guzman  Northern Mariana Islands
# 673      David Trevino                    Turkey
# 695     Lori Hernandez                    Poland
# 774       Andrew Logan                     Nauru
# 779      Angela Thomas                   Namibia
# 785       Andrew Myers                 Greenland
# 849         Sean Huang                  Suriname

# %%
row = purchase.loc[131]
print(row)
# Out:
# customerid                         3132
# productid                           432
# purchaseid                         5132
# transactionid                       373
# purchasedate        2023-08-11 00:00:00
# purchaseprice                    509.21
# purchasequantity                      4
# country                       Venezuela
# Name: 131, dtype: object

# %%
#Analyze purchase trends over time (monthly, quarterly, yearly)
purchase['Month'] = purchase['purchasedate'].dt.month
purchase['Year'] = purchase['purchasedate'].dt.year
purchase
# Out:
#      customerid  productid  purchaseid  transactionid purchasedate  \
# 0          3001        301        5001            224   2023-06-26
# 1          3002        302        5002            650   2023-06-26
# 2          3003        303        5003            152   2023-06-27
# 3          3004        304        5004            376   2023-06-27
# 4          3005        305        5005            635   2023-06-27
# ..          ...        ...         ...            ...          ...
# 995        3996       1296        5996            439   2024-06-24
# 996        3997       1297        5997            864   2024-06-24
# 997        3998       1298        5998             37   2024-06-25
# 998        3999       1299        5999             83   2024-06-25
# 999        4000       1300        6000            854   2024-06-25
#
#      purchaseprice  purchasequantity  \
# 0            54.96                 3
# 1           477.05                 1
# 2           579.06                 3
# 3           757.42                 3
# 4           316.81                 1
# ..             ...               ...
# 995         401.99                 1
# 996         527.87                 5
# 997         568.75                 5
# 998         813.03                 2
# 999         816.81                 3
#
#                                                country  Month  Year
# 0                                              Senegal      6  2023
# 1    British Indian Ocean Territory (Chagos Archipe...      6  2023
# 2                                              Romania      6  2023
# 3                                                Malta      6  2023
# 4                                                Niger      6  2023
# ..                                                 ...    ...   ...
# 995                                      Guinea-Bissau      6  2024
# 996                                        Philippines      6  2024
# 997                        French Southern Territories      6  2024
# 998                                             Norway      6  2024
# 999                                               Fiji      6  2024
#
# [1000 rows x 10 columns]

# %%
monthly_sales = purchase.groupby("Month")["purchaseprice"].sum()
monthly_sales
# Out:
# Month
# 1     43575.14
# 2     41393.77
# 3     37442.66
# 4     34165.64
# 5     42799.97
# 6     31563.91
# 7     47956.69
# 8     33493.46
# 9     46764.80
# 10    38368.97
# 11    39839.29
# 12    51910.42
# Name: purchaseprice, dtype: float64

# %%
# Plot monthly sales trends
monthly_sales.plot(kind='line', figsize=(10, 6), title='Monthly Purchase Trend',color='red')
# Out:
# <Axes: title={'center': 'Monthly Purchase Trend'}, xlabel='Month'>

# %%
# Convert to quarterly periods
purchase['Quarter'] = purchase['purchasedate'].dt.to_period('Q')
purchase
# Out:
#      customerid  productid  purchaseid  transactionid purchasedate  \
# 0          3001        301        5001            224   2023-06-26
# 1          3002        302        5002            650   2023-06-26
# 2          3003        303        5003            152   2023-06-27
# 3          3004        304        5004            376   2023-06-27
# 4          3005        305        5005            635   2023-06-27
# ..          ...        ...         ...            ...          ...
# 995        3996       1296        5996            439   2024-06-24
# 996        3997       1297        5997            864   2024-06-24
# 997        3998       1298        5998             37   2024-06-25
# 998        3999       1299        5999             83   2024-06-25
# 999        4000       1300        6000            854   2024-06-25
#
#      purchaseprice  purchasequantity  \
# 0            54.96                 3
# 1           477.05                 1
# 2           579.06                 3
# 3           757.42                 3
# 4           316.81                 1
# ..             ...               ...
# 995         401.99                 1
# 996         527.87                 5
# 997         568.75                 5
# 998         813.03                 2
# 999         816.81                 3
#
#                                                country  Month  Year Quarter
# 0                                              Senegal      6  2023  2023Q2
# 1    British Indian Ocean Territory (Chagos Archipe...      6  2023  2023Q2
# 2                                              Romania      6  2023  2023Q2
# 3                                                Malta      6  2023  2023Q2
# 4                                                Niger      6  2023  2023Q2
# ..                                                 ...    ...   ...     ...
# 995                                      Guinea-Bissau      6  2024  2024Q2
# 996                                        Philippines      6  2024  2024Q2
# 997                        French Southern Territories      6  2024  2024Q2
# 998                                             Norway      6  2024  2024Q2
# 999                                               Fiji      6  2024  2024Q2
#
# [1000 rows x 11 columns]

# %%
# Group by Quarter and calculate total sales
quarterly_sales = purchase.groupby('Quarter')['purchaseprice'].sum()

# %%
# Plot Quarterly sales trends
quarterly_sales.plot(kind='line', figsize=(10, 6), title='Quarterly Purchase Trends',linestyle='-',color='red')
# Out:
# <Axes: title={'center': 'Quarterly Purchase Trends'}, xlabel='Quarter'>

# %%
yearly_sales = purchase.groupby('Year')['purchaseprice'].sum()

# Plot yearly sales trends
yearly_sales.plot(kind='line', figsize=(10, 6), title='Yearly Purchase Trends',linestyle='--',color='red')

# Add grid line

plt.grid(True)

# Rotating the xticks

plt.xticks(rotation = 45)
# Out:
# (array([2022.8, 2023. , 2023.2, 2023.4, 2023.6, 2023.8, 2024. , 2024.2]),
#  [Text(2022.8000000000002, 0, '2022.8'),
#   Text(2023.0, 0, '2023.0'),
#   Text(2023.2, 0, '2023.2'),
#   Text(2023.4, 0, '2023.4'),
#   Text(2023.6, 0, '2023.6'),
#   Text(2023.8000000000002, 0, '2023.8'),
#   Text(2024.0, 0, '2024.0'),
#   Text(2024.2, 0, '2024.2')])

# %%
#Identify the top-performing product categories.
merge2 = pd.merge(purchase,products,on='productid')
category_analysis = merge2.groupby("productcategory")["purchaseprice"].sum()
category_analysis
# Out:
# productcategory
# Electronics        3313.94
# Home Appliances    4576.64
# Name: purchaseprice, dtype: float64
